# %% [markdown]
# ### 4 class

# %% [markdown]
# - train : validation = 8 : 2
# ![image.png](attachment:image.png)

# %% [markdown]
# - Simple Network
#
# ![image.png](attachment:image.png)

# %% [raw]
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.70      0.68        82
#          1.0       0.00      0.00      0.00        49
#          2.0       0.22      0.77      0.35        22
#          3.0       0.00      0.00      0.00         8
#
#     accuracy                           0.46       161
#    macro avg       0.22      0.37      0.26       161
# weighted avg       0.37      0.46      0.40       161

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### binary class

# %% [markdown]
# - train : validation = 8 : 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - Simple Network
#
# ![download.png](attachment:download.png)

# %% [raw]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.31      0.48       131
#          1.0       0.25      1.00      0.40        30
#
#     accuracy                           0.44       161
#    macro avg       0.62      0.66      0.44       161
# weighted avg       0.86      0.44      0.46       161

# %% [markdown]
# ![download%20%281%29.png](attachment:download%20%281%29.png)
